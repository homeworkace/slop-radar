# %% [markdown]
# # Installing requirements

# %%
# !pip install huggingface_hub
# !pip install datasets
# !pip install scikit-learn
# !pip install matplotlib

from huggingface_hub import notebook_login
import datasets
from tqdm import tqdm
import numpy as np
import pandas as pd
import json
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: huggingface_hub in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (0.26.5)
# Requirement already satisfied: filelock in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: colorama in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub) (2023.11.17)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: datasets in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (3.2.0)
# Requirement already satisfied: filelock in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from datasets) (2.2.0)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.26.5)
# Requirement already satisfied: packaging in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.32.2->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.32.2->datasets) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.32.2->datasets) (2023.11.17)
# Requirement already satisfied: colorama in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting matplotlib
#   Downloading matplotlib-3.10.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.55.3-cp312-cp312-win_amd64.whl.metadata (168 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.0.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\rickc\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.10.0-cp312-cp312-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.0 MB 9.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.4/8.0 MB 9.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.0 MB 9.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 8.9 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.0 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 7.4 MB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp312-cp312-win_amd64.whl (220 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.3-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------------------------------- ------ 1.8/2.2 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 8.9 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.7-cp312-cp312-win_amd64.whl (55 kB)
# Downloading pillow-11.0.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------------------------------- ------- 2.1/2.6 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 9.2 MB/s eta 0:00:00
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.3 kiwisolver-1.4.7 matplotlib-3.10.0 pillow-11.0.0 pyparsing-3.2.0

# %% [markdown]
# # Download the dataset

# %%
notebook_login()
hugging_face_dataset = datasets.load_dataset('lmsys/chatbot_arena_conversations')
dataset = hugging_face_dataset['train'].to_pandas()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
dataset[dataset['turn'] > 3][:1]
# Out:
#                          question_id     model_a     model_b   winner  \
# 33  8120899314f74641b09c2aa114d4d253  alpaca-13b  vicuna-13b  model_b
#
#              judge                                     conversation_a  \
# 33  arena_user_316  [{'content': 'Salut ! Comment ça va ce matin ?...
#
#                                        conversation_b  turn  anony language  \
# 33  [{'content': 'Salut ! Comment ça va ce matin ?...     6   True   French
#
#           tstamp                                  openai_moderation  \
# 33  1.682354e+09  {'categories': {'harassment': False, 'harassme...
#
#                                        toxic_chat_tag
# 33  {'roberta-large': {'flagged': False, 'probabil...

# %% [markdown]
# # Create text-author pairs

# %%
# Initialize an empty list for processed data
text_author_pairs = []

# Iterate through each row of the DataFrame
for _, row in dataset.iterrows():
    # Process conversation_a (assistant role)
    for message in row["conversation_a"]:
        if message["role"] == "assistant":
            text_author_pairs.append({
                "text": message["content"],
                "author": row["model_a"]
            })

    # Process conversation_b (assistant role)
    for message in row["conversation_b"]:
        if message["role"] == "assistant":
            text_author_pairs.append({
                "text": message["content"],
                "author": row["model_b"]
            })

    # Process user messages (common across both conversations)
    # for message in row["conversation_a"]:  # Check only `conversation_a` since user messages are identical
    #     if message["role"] == "user":
    #         text_author_pairs.append({
    #             "text": message["content"],
    #             "author": "human"
    #         })

# %% [markdown]
# # Create token count vectors for each text

# %%
# Extract paragraphs and their authors
paragraphs = [entry["text"] for entry in text_author_pairs]
authors = [entry["author"] for entry in text_author_pairs]

# Vectorize the paragraphs
vectorizer = CountVectorizer()
text_vectors = vectorizer.fit_transform(paragraphs)  # Each row is a paragraph

# %% [markdown]
# # Group texts by author

# %%
# Sum all token instances by author.
author_vectors = {}
author_count = {} # Also count how many texts are attributed to each author
for i, author in enumerate(tqdm(authors)):
    if author == 'human' :
        continue
    if author not in author_vectors:
        # Add this new author to the list.
        author_vectors[author] = text_vectors[i].toarray()
        author_count[author] = 1
    else:
        # The resulting vectors represent the number of times each token appears in that author's entire corpus.
        author_vectors[author] += text_vectors[i].toarray()
        author_count[author] += 1

# Convert to a more readable format (if needed)
author_df = pd.DataFrame({author: vector.flatten() for author, vector in author_vectors.items()},
                         index=vectorizer.get_feature_names_out())

author_df
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 78632/78632 [00:50<00:00, 1557.75it/s]
#                            chatglm-6b  koala-13b  oasst-pythia-12b  \
# 00                                136         64               238
# 000                               114        204               129
# 0000                                2          0                 0
# 00000                               0          0                 0
# 000000                              1          2                 0
# ...                               ...        ...               ...
# 힘을                                  0          0                 0
# ３丁目のトメさんがくれたチキン味のカリカリについて           0          0                 0
# ５点満点で採点してにゃ                         0          0                 0
# 𝘀𝗶𝗺𝗽𝗹𝗲                              0          0                 0
# 𝘀𝘂𝗽𝗲𝗿𝗵𝘂𝗺𝗮𝗻                          0          0                 0
#
#                            alpaca-13b  vicuna-13b  dolly-v2-12b  \
# 00                                 47         155            18
# 000                                37         227           100
# 0000                                0           1             1
# 00000                               0           0             0
# 000000                              0           1             2
# ...                               ...         ...           ...
# 힘을                                  0           0             0
# ３丁目のトメさんがくれたチキン味のカリカリについて           0           0             0
# ５点満点で採点してにゃ                         0           0             0
# 𝘀𝗶𝗺𝗽𝗹𝗲                              0           0             0
# 𝘀𝘂𝗽𝗲𝗿𝗵𝘂𝗺𝗮𝗻                          0           0             0
#
#                            stablelm-tuned-alpha-7b  llama-13b  fastchat-t5-3b  \
# 00                                              52         23              37
# 000                                             54         69              86
# 0000                                             0          0               1
# 00000                                            0          0               0
# 000000                                           1          0               0
# ...                                            ...        ...             ...
# 힘을                                               0          0               0
# ３丁目のトメさんがくれたチキン味のカリカリについて                        0          1               0
# ５点満点で採点してにゃ                                      0          1               0
# 𝘀𝗶𝗺𝗽𝗹𝗲                                           0          0               0
# 𝘀𝘂𝗽𝗲𝗿𝗵𝘂𝗺𝗮𝗻                                       0          0               0
#
#                            gpt-3.5-turbo  gpt-4  RWKV-4-Raven-14B  claude-v1  \
# 00                                    39     78                27         57
# 000                                  149    216                80        464
# 0000                                   0      0                 0          0
# 00000                                  0      0                 0          0
# 000000                                 1      0                 0          0
# ...                                  ...    ...               ...        ...
# 힘을                                     1      0                 0          0
# ３丁目のトメさんがくれたチキン味のカリカリについて              0      0                 0          0
# ５点満点で採点してにゃ                            0      0                 0          0
# 𝘀𝗶𝗺𝗽𝗹𝗲                                 0      1                 0          0
# 𝘀𝘂𝗽𝗲𝗿𝗵𝘂𝗺𝗮𝗻                             0      1                 0          0
#
#                            mpt-7b-chat  palm-2  claude-instant-v1  vicuna-7b  \
# 00                                  32      87                 18         83
# 000                                 94     252                227         60
# 0000                                 0       1                  0          8
# 00000                                0       0                  1          0
# 000000                               0       2                  1          0
# ...                                ...     ...                ...        ...
# 힘을                                   0       0                  0          0
# ３丁目のトメさんがくれたチキン味のカリカリについて            0       0                  0          0
# ５点満点で採点してにゃ                          0       0                  0          0
# 𝘀𝗶𝗺𝗽𝗹𝗲                               0       0                  0          0
# 𝘀𝘂𝗽𝗲𝗿𝗵𝘂𝗺𝗮𝗻                           0       0                  0          0
#
#                            wizardlm-13b  gpt4all-13b-snoozy  guanaco-33b
# 00                                    6                  28            3
# 000                                  40                  45           20
# 0000                                  3                  11            1
# 00000                                 0                   0            0
# 000000                                0                   0            0
# ...                                 ...                 ...          ...
# 힘을                                    0                   0            0
# ３丁目のトメさんがくれたチキン味のカリカリについて             0                   0            0
# ５点満点で採点してにゃ                           0                   0            0
# 𝘀𝗶𝗺𝗽𝗹𝗲                                0                   0            0
# 𝘀𝘂𝗽𝗲𝗿𝗵𝘂𝗺𝗮𝗻                            0                   0            0
#
# [182603 rows x 20 columns]

# %%
# Find the average text length of each author. 
author_length = {author: np.sum(vector) / author_count[author] for author, vector in author_vectors.items()}

# Normalise the length of each corpus.
for author in author_count :
    author_df[author] /= np.sum(author_df[author])
    
# Since it has been lost, add the average text length as a separate feature.
author_df = pd.concat([author_df, pd.DataFrame(author_length, index = ['_length'])])

author_df
# Out:
#                            chatglm-6b   koala-13b  oasst-pythia-12b  \
# 00                           0.000271    0.000073          0.000416
# 000                          0.000227    0.000234          0.000225
# 0000                         0.000004    0.000000          0.000000
# 00000                        0.000000    0.000000          0.000000
# 000000                       0.000002    0.000002          0.000000
# ...                               ...         ...               ...
# ３丁目のトメさんがくれたチキン味のカリカリについて    0.000000    0.000000          0.000000
# ５点満点で採点してにゃ                  0.000000    0.000000          0.000000
# 𝘀𝗶𝗺𝗽𝗹𝗲                       0.000000    0.000000          0.000000
# 𝘀𝘂𝗽𝗲𝗿𝗵𝘂𝗺𝗮𝗻                   0.000000    0.000000          0.000000
# _length                    132.281456  131.838700         99.134049
#
#                            alpaca-13b  vicuna-13b  dolly-v2-12b  \
# 00                           0.000186    0.000175      0.000093
# 000                          0.000147    0.000256      0.000519
# 0000                         0.000000    0.000001      0.000005
# 00000                        0.000000    0.000000      0.000000
# 000000                       0.000000    0.000001      0.000010
# ...                               ...         ...           ...
# ３丁目のトメさんがくれたチキン味のカリカリについて    0.000000    0.000000      0.000000
# ５点満点で採点してにゃ                  0.000000    0.000000      0.000000
# 𝘀𝗶𝗺𝗽𝗹𝗲                       0.000000    0.000000      0.000000
# 𝘀𝘂𝗽𝗲𝗿𝗵𝘂𝗺𝗮𝗻                   0.000000    0.000000      0.000000
# _length                     46.677533  123.486445     58.253704
#
#                            stablelm-tuned-alpha-7b  llama-13b  fastchat-t5-3b  \
# 00                                        0.000136   0.000175        0.000092
# 000                                       0.000141   0.000524        0.000214
# 0000                                      0.000000   0.000000        0.000002
# 00000                                     0.000000   0.000000        0.000000
# 000000                                    0.000003   0.000000        0.000000
# ...                                            ...        ...             ...
# ３丁目のトメさんがくれたチキン味のカリカリについて                 0.000000   0.000008        0.000000
# ５点満点で採点してにゃ                               0.000000   0.000008        0.000000
# 𝘀𝗶𝗺𝗽𝗹𝗲                                    0.000000   0.000000        0.000000
# 𝘀𝘂𝗽𝗲𝗿𝗵𝘂𝗺𝗮𝗻                                0.000000   0.000000        0.000000
# _length                                 117.806094  55.029252      108.862936
#
#                            gpt-3.5-turbo       gpt-4  RWKV-4-Raven-14B  \
# 00                              0.000071    0.000116          0.000057
# 000                             0.000271    0.000321          0.000169
# 0000                            0.000000    0.000000          0.000000
# 00000                           0.000000    0.000000          0.000000
# 000000                          0.000002    0.000000          0.000000
# ...                                  ...         ...               ...
# ３丁目のトメさんがくれたチキン味のカリカリについて       0.000000    0.000000          0.000000
# ５点満点で採点してにゃ                     0.000000    0.000000          0.000000
# 𝘀𝗶𝗺𝗽𝗹𝗲                          0.000000    0.000001          0.000000
# 𝘀𝘂𝗽𝗲𝗿𝗵𝘂𝗺𝗮𝗻                      0.000000    0.000001          0.000000
# _length                        98.505652  136.209909        107.774135
#
#                             claude-v1  mpt-7b-chat      palm-2  \
# 00                           0.000080     0.000110    0.000172
# 000                          0.000653     0.000324    0.000498
# 0000                         0.000000     0.000000    0.000002
# 00000                        0.000000     0.000000    0.000000
# 000000                       0.000000     0.000000    0.000004
# ...                               ...          ...         ...
# ３丁目のトメさんがくれたチキン味のカリカリについて    0.000000     0.000000    0.000000
# ５点満点で採点してにゃ                  0.000000     0.000000    0.000000
# 𝘀𝗶𝗺𝗽𝗹𝗲                       0.000000     0.000000    0.000000
# 𝘀𝘂𝗽𝗲𝗿𝗵𝘂𝗺𝗮𝗻                   0.000000     0.000000    0.000000
# _length                    157.880667    82.476962  143.570740
#
#                            claude-instant-v1   vicuna-7b  wizardlm-13b  \
# 00                                  0.000041    0.000187      0.000036
# 000                                 0.000519    0.000135      0.000243
# 0000                                0.000000    0.000018      0.000018
# 00000                               0.000002    0.000000      0.000000
# 000000                              0.000002    0.000000      0.000000
# ...                                      ...         ...           ...
# ３丁目のトメさんがくれたチキン味のカリカリについて           0.000000    0.000000      0.000000
# ５点満点で採点してにゃ                         0.000000    0.000000      0.000000
# 𝘀𝗶𝗺𝗽𝗹𝗲                              0.000000    0.000000      0.000000
# 𝘀𝘂𝗽𝗲𝗿𝗵𝘂𝗺𝗮𝗻                          0.000000    0.000000      0.000000
# _length                           140.194418  123.839296    118.277498
#
#                            gpt4all-13b-snoozy  guanaco-33b
# 00                                   0.000227     0.000017
# 000                                  0.000365     0.000112
# 0000                                 0.000089     0.000006
# 00000                                0.000000     0.000000
# 000000                               0.000000     0.000000
# ...                                       ...          ...
# ３丁目のトメさんがくれたチキン味のカリカリについて            0.000000     0.000000
# ５点満点で採点してにゃ                          0.000000     0.000000
# 𝘀𝗶𝗺𝗽𝗹𝗲                               0.000000     0.000000
# 𝘀𝘂𝗽𝗲𝗿𝗵𝘂𝗺𝗮𝗻                           0.000000     0.000000
# _length                             86.542456   143.102564
#
# [182604 rows x 20 columns]

# %%
author_df.loc['00']
# Out:
# chatglm-6b                 0.000271
# koala-13b                  0.000073
# oasst-pythia-12b           0.000416
# alpaca-13b                 0.000186
# vicuna-13b                 0.000175
# dolly-v2-12b               0.000093
# stablelm-tuned-alpha-7b    0.000136
# llama-13b                  0.000175
# fastchat-t5-3b             0.000092
# gpt-3.5-turbo              0.000071
# gpt-4                      0.000116
# RWKV-4-Raven-14B           0.000057
# claude-v1                  0.000080
# mpt-7b-chat                0.000110
# palm-2                     0.000172
# claude-instant-v1          0.000041
# vicuna-7b                  0.000187
# wizardlm-13b               0.000036
# gpt4all-13b-snoozy         0.000227
# guanaco-33b                0.000017
# Name: 00, dtype: float64

# %%
common_tokens_only = author_df[author_df.ne(0).sum(axis=1) == 20]

common_tokens_only
# Out:
#          chatglm-6b   koala-13b  oasst-pythia-12b  alpaca-13b  vicuna-13b  \
# 00         0.000271    0.000073          0.000416    0.000186    0.000175
# 000        0.000227    0.000234          0.000225    0.000147    0.000256
# 01         0.000030    0.000019          0.000073    0.000028    0.000068
# 03         0.000006    0.000009          0.000035    0.000004    0.000018
# 05         0.000028    0.000005          0.000077    0.000099    0.000026
# ...             ...         ...               ...         ...         ...
# zero       0.000064    0.000073          0.000044    0.000048    0.000066
# zone       0.000004    0.000028          0.000019    0.000036    0.000026
# zu         0.000173    0.000085          0.000372    0.000286    0.000254
# на         0.000050    0.000002          0.000040    0.000067    0.000087
# _length  132.281456  131.838700         99.134049   46.677533  123.486445
#
#          dolly-v2-12b  stablelm-tuned-alpha-7b  llama-13b  fastchat-t5-3b  \
# 00           0.000093                 0.000136   0.000175        0.000092
# 000          0.000519                 0.000141   0.000524        0.000214
# 01           0.000291                 0.000003   0.000023        0.000022
# 03           0.000047                 0.000003   0.000099        0.000022
# 05           0.000119                 0.000008   0.000023        0.000010
# ...               ...                      ...        ...             ...
# zero         0.000099                 0.000016   0.000046        0.000097
# zone         0.000067                 0.000016   0.000038        0.000025
# zu           0.000171                 0.000138   0.000046        0.000340
# на           0.000057                 0.000052   0.000023        0.000094
# _length     58.253704               117.806094  55.029252      108.862936
#
#          gpt-3.5-turbo       gpt-4  RWKV-4-Raven-14B   claude-v1  mpt-7b-chat  \
# 00            0.000071    0.000116          0.000057    0.000080     0.000110
# 000           0.000271    0.000321          0.000169    0.000653     0.000324
# 01            0.000026    0.000034          0.000114    0.000041     0.000066
# 03            0.000009    0.000010          0.000013    0.000001     0.000010
# 05            0.000031    0.000037          0.000023    0.000046     0.000014
# ...                ...         ...               ...         ...          ...
# zero          0.000097    0.000105          0.000068    0.000084     0.000083
# zone          0.000128    0.000028          0.000025    0.000044     0.000024
# zu            0.000512    0.000490          0.000306    0.000300     0.000345
# на            0.000120    0.000140          0.000065    0.000117     0.000138
# _length      98.505652  136.209909        107.774135  157.880667    82.476962
#
#              palm-2  claude-instant-v1   vicuna-7b  wizardlm-13b  \
# 00         0.000172           0.000041    0.000187      0.000036
# 000        0.000498           0.000519    0.000135      0.000243
# 01         0.000036           0.000039    0.000084      0.000043
# 03         0.000020           0.000011    0.000009      0.000030
# 05         0.000024           0.000023    0.000007      0.000043
# ...             ...                ...         ...           ...
# zero       0.000063           0.000073    0.000068      0.000213
# zone       0.000038           0.000034    0.000016      0.000049
# zu         0.000002           0.000284    0.000241      0.000274
# на         0.000002           0.000089    0.000111      0.000122
# _length  143.570740         140.194418  123.839296    118.277498
#
#          gpt4all-13b-snoozy  guanaco-33b
# 00                 0.000227     0.000017
# 000                0.000365     0.000112
# 01                 0.000146     0.000006
# 03                 0.000032     0.000017
# 05                 0.000016     0.000006
# ...                     ...          ...
# zero               0.000049     0.000078
# zone               0.000008     0.000011
# zu                 0.000041     0.000431
# на                 0.000008     0.000123
# _length           86.542456   143.102564
#
# [3909 rows x 20 columns]

# %% [markdown]
# # Centering

# %%
features_mean = {feature: np.mean(common_tokens_only.loc[feature]) for feature in common_tokens_only.index}
for feature in common_tokens_only.index :
    common_tokens_only.loc[feature] -= features_mean[feature]

common_tokens_only
# Out:
#          chatglm-6b  koala-13b  oasst-pythia-12b  alpaca-13b    vicuna-13b  \
# 00         0.000135  -0.000063          0.000279    0.000050  3.788724e-05
# 000       -0.000078  -0.000071         -0.000080   -0.000158 -4.931819e-05
# 01        -0.000030  -0.000040          0.000014   -0.000032  8.116125e-06
# 03        -0.000014  -0.000011          0.000015   -0.000016 -2.299262e-06
# 05        -0.000005  -0.000029          0.000044    0.000066 -7.290701e-06
# ...             ...        ...               ...         ...           ...
# zero      -0.000013  -0.000003         -0.000033   -0.000029 -1.019177e-05
# zone      -0.000029  -0.000006         -0.000014    0.000003 -7.241709e-06
# zu        -0.000081  -0.000170          0.000118    0.000031 -1.312166e-07
# на        -0.000026  -0.000073         -0.000035   -0.000008  1.130474e-05
# _length   21.694233  21.251477        -11.453174  -63.909690  1.289922e+01
#
#          dolly-v2-12b  stablelm-tuned-alpha-7b  llama-13b  fastchat-t5-3b  \
# 00          -0.000043            -7.573355e-07   0.000038       -0.000045
# 000          0.000214            -1.637968e-04   0.000219       -0.000091
# 01           0.000231            -5.682068e-05  -0.000037       -0.000037
# 03           0.000026            -1.769979e-05   0.000078        0.000002
# 05           0.000086            -2.534669e-05  -0.000010       -0.000023
# ...               ...                      ...        ...             ...
# zero         0.000022            -6.093946e-05  -0.000031        0.000020
# zone         0.000034            -1.745972e-05   0.000005       -0.000008
# zu          -0.000083            -1.160967e-04  -0.000209        0.000086
# на          -0.000018            -2.313058e-05  -0.000053        0.000019
# _length    -52.333519             7.218871e+00 -55.557971       -1.724287
#
#          gpt-3.5-turbo      gpt-4  RWKV-4-Raven-14B  claude-v1  mpt-7b-chat  \
# 00           -0.000066  -0.000021         -0.000080  -0.000056    -0.000026
# 000          -0.000033   0.000016         -0.000136   0.000348     0.000019
# 01           -0.000034  -0.000025          0.000055  -0.000019     0.000006
# 03           -0.000011  -0.000010         -0.000008  -0.000019    -0.000010
# 05           -0.000002   0.000004         -0.000010   0.000013    -0.000019
# ...                ...        ...               ...        ...          ...
# zero          0.000020   0.000029         -0.000009   0.000008     0.000006
# zone          0.000094  -0.000005         -0.000008   0.000010    -0.000009
# zu            0.000257   0.000235          0.000052   0.000045     0.000090
# на            0.000045   0.000064         -0.000010   0.000041     0.000063
# _length     -12.081571  25.622686         -2.813089  47.293443   -28.110261
#
#                palm-2  claude-instant-v1  vicuna-7b  wizardlm-13b  \
# 00       3.519423e-05          -0.000095   0.000051     -0.000100
# 000      1.927756e-04           0.000215  -0.000169     -0.000062
# 01      -2.388649e-05          -0.000021   0.000024     -0.000017
# 03      -5.642026e-07          -0.000009  -0.000011      0.000010
# 05      -9.486762e-06          -0.000010  -0.000026      0.000009
# ...               ...                ...        ...           ...
# zero    -1.342101e-05          -0.000003  -0.000009      0.000136
# zone     4.386004e-06           0.000001  -0.000017      0.000015
# zu      -2.525927e-04           0.000029  -0.000013      0.000019
# на      -7.340892e-05           0.000014   0.000035      0.000046
# _length  3.298352e+01          29.607194  13.252072      7.690275
#
#          gpt4all-13b-snoozy  guanaco-33b
# 00                 0.000090    -0.000120
# 000                0.000060    -0.000193
# 01                 0.000087    -0.000054
# 03                 0.000012    -0.000004
# 05                -0.000017    -0.000028
# ...                     ...          ...
# zero              -0.000028     0.000002
# zone              -0.000025    -0.000022
# zu                -0.000214     0.000177
# на                -0.000067     0.000048
# _length          -24.044767    32.515341
#
# [3909 rows x 20 columns]

# %% [markdown]
# # Standardisation

# %%
features_std = {feature: np.std(common_tokens_only.loc[feature]) for feature in common_tokens_only.index}
for feature in common_tokens_only.index :
    common_tokens_only.loc[feature] /= features_std[feature]

common_tokens_only
# Out:
#          chatglm-6b  koala-13b  oasst-pythia-12b  alpaca-13b  vicuna-13b  \
# 00         1.461036  -0.686436          3.030776    0.541540    0.411307
# 000       -0.504904  -0.462019         -0.517668   -1.029055   -0.321084
# 01        -0.465162  -0.629323          0.219676   -0.498803    0.127882
# 03        -0.668707  -0.519809          0.682613   -0.762700   -0.107294
# 05        -0.172768  -0.938030          1.432876    2.165385   -0.239138
# ...             ...        ...               ...         ...         ...
# zero      -0.337611  -0.085178         -0.868530   -0.764616   -0.268730
# zone      -1.119312  -0.215675         -0.534488    0.098958   -0.278094
# zu        -0.574589  -1.202717          0.833033    0.220629   -0.000930
# на        -0.577862  -1.654298         -0.796748   -0.179408    0.255867
# _length    0.706522   0.692103         -0.372999   -2.081365    0.420093
#
#          dolly-v2-12b  stablelm-tuned-alpha-7b  llama-13b  fastchat-t5-3b  \
# 00          -0.468760                -0.008222   0.413005       -0.485615
# 000          1.394599                -1.066391   1.426423       -0.594491
# 01           3.643806                -0.895297  -0.577504       -0.584304
# 03           1.232200                -0.825949   3.658856        0.095082
# 05           2.827592                -0.831382  -0.341224       -0.762653
# ...               ...                      ...        ...             ...
# zero         0.580386                -1.606809  -0.818761        0.533535
# zone         1.318943                -0.670483   0.185623       -0.318822
# zu          -0.590090                -0.822735  -1.481137        0.606968
# на          -0.413830                -0.523528  -1.190573        0.429654
# _length     -1.704360                 0.235099  -1.809372       -0.056155
#
#          gpt-3.5-turbo     gpt-4  RWKV-4-Raven-14B  claude-v1  mpt-7b-chat  \
# 00           -0.711873 -0.225943         -0.863868  -0.612133    -0.285152
# 000          -0.217865  0.102896         -0.884575   2.267036     0.125456
# 01           -0.534637 -0.398425          0.861073  -0.293306     0.095900
# 03           -0.522851 -0.462905         -0.356361  -0.882185    -0.465114
# 05           -0.072741  0.128960         -0.326225   0.435062    -0.636034
# ...                ...       ...               ...        ...          ...
# zero          0.525465  0.759245         -0.237604   0.206629     0.162063
# zone          3.624173 -0.189215         -0.298924   0.403135    -0.345493
# zu            1.823379  1.667968          0.366830   0.320578     0.639733
# на            1.014911  1.452479         -0.223897   0.937969     1.415787
# _length      -0.393464  0.834461         -0.091615   1.540219    -0.915475
#
#            palm-2  claude-instant-v1  vicuna-7b  wizardlm-13b  \
# 00       0.382071          -1.035934   0.550429     -1.087201
# 000      1.255056           1.397059  -1.103325     -0.402051
# 01      -0.376368          -0.323489   0.379257     -0.266070
# 03      -0.026328          -0.413933  -0.526611      0.470295
# 05      -0.311170          -0.337865  -0.866395      0.307088
# ...           ...                ...        ...           ...
# zero    -0.353876          -0.089293  -0.234937      3.589104
# zone     0.168430           0.045712  -0.665800      0.594821
# zu      -1.790033           0.206890  -0.092732      0.134283
# на      -1.661506           0.313791   0.796736      1.045197
# _length  1.074183           0.964226   0.431584      0.250451
#
#          gpt4all-13b-snoozy  guanaco-33b
# 00                 0.981721    -1.300749
# 000                0.390725    -1.255822
# 01                 1.363332    -0.848237
# 03                 0.565698    -0.163997
# 05                -0.556528    -0.904810
# ...                     ...          ...
# zero              -0.737301     0.046817
# zone              -0.961074    -0.842416
# zu                -1.516707     1.251378
# на                -1.522672     1.081931
# _length           -0.783073     1.058936
#
# [3909 rows x 20 columns]

# %%
print(np.mean(common_tokens_only.loc['_length']))
print(np.std(common_tokens_only.loc['_length']))

print(np.sum([np.std(common_tokens_only.loc[feature]) for feature in common_tokens_only.index]))
# Out:
# 5.773159728050814e-16
# 0.9999999999999999
# 3909.0

# %%
# author_df.to_csv('bruh.csv')

# %%
# Extracting the two features
x_token = 'zu'
y_token = '_length'

# Creating the scatter plot
feature_graph_figure = plt.figure(figsize=(8, 6))
feature_graph = feature_graph_figure.subplots()
feature_graph.scatter(common_tokens_only.loc[x_token], common_tokens_only.loc[y_token], color='blue', alpha=0.7)
feature_graph.set_xlabel("Feature '" + x_token + "'")
feature_graph.set_ylabel("Feature '" + y_token + "'")
feature_graph.grid(True)
feature_graph_figure.show()
# Out:
# C:\Users\rickc\AppData\Local\Temp\ipykernel_5176\3607572353.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   feature_graph_figure.show()

# %%
def power_iteration(A, num_iter=1000, tol=1e-7):
    """
    Power Iteration to compute the largest eigenvector of matrix A.
    Args:
        A (np.ndarray): Input symmetric matrix.
        num_iter (int): Number of iterations.
        tol (float): Tolerance for convergence.

    Returns:
        eigenvector (np.ndarray): Approximation of the largest eigenvector.
        eigenvalue (float): Corresponding eigenvalue.
    """
    b = np.random.rand(A.shape[1])  # Random initial vector
    b = b / np.linalg.norm(b)

    error_meter = tqdm(position = 0, total=7, bar_format='{bar} | {postfix}')
    for i in range(num_iter):
        b_next = A @ b  # Matrix-vector multiplication
        b_next = b_next / np.linalg.norm(b_next)  # Normalize
        
        # Check for convergence
        error = np.linalg.norm(b_next - b)
        b = b_next
        error_meter.update(-np.log10(error) - error_meter.n)
        error_meter.set_postfix_str('{:.2E}'.format(error) + ' of error after ' + str(i + 1) + ' iterations...')
        if error < tol:
            error_meter.close()
            break

    eigenvalue = b.T @ A @ b  # Rayleigh quotient for eigenvalue
    return b, eigenvalue

# %%
def pca_power_iteration(data, num_components=2, num_iter=1000):
    """
    PCA using Power Iteration to compute the principal components.
    Args:
        data (np.ndarray): Input data matrix (rows are samples, columns are features).
        num_components (int): Number of principal components to compute.
        num_iter (int): Number of iterations for power iteration.

    Returns:
        components (list): List of principal components (eigenvectors).
        explained_variance (list): List of corresponding eigenvalues.
    """
    # Step 1: Center the data
    covariance_matrix = np.cov(data, rowvar=True, ddof = 0)
    
    # Compute covariance matrix manually
    n = data.shape[1]  # Number of samples (columns in your case)
    covariance_matrix = (data @ data.T) / n

    components = []
    explained_variance = []

    for i in range(num_components):
        # Step 2: Compute the largest eigenvector using power iteration
        eigenvector, eigenvalue = power_iteration(covariance_matrix, num_iter=num_iter)
        components.append(eigenvector)
        explained_variance.append(eigenvalue)
        
        # Step 3: Deflate the covariance matrix
        covariance_matrix -= eigenvalue * np.outer(eigenvector, eigenvector)
        if np.linalg.norm(covariance_matrix, ord='fro') < 1e-10 :
            print('Stopped as all variance has been extracted after computing ' + str(i + 1) + ' PCs.')
            break
        
    return components, explained_variance

# %%
components, explained_variance = pca_power_iteration(common_tokens_only, num_components=20)
# Out:
# 3909.0
# 3909.0
#                                                                                                                      | C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# █████████████████████████████████████████████████████████████████████████▉ | , 1.01E-07 of error after 57 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# ██████████████████████████████████████████████████████████████████████████ | , 7.57E-08 of error after 58 iterations...
# 3370.0916443575425
# █████████████████████████████████████████████████████████████████████████▍ | , 1.13E-07 of error after 83 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# ██████████████████████████████████████████████████████████████████████████ | , 9.57E-08 of error after 84 iterations...
# 2966.967721177197
# █████████████████████████████████████████████████████████████████████████▌ | , 1.10E-07 of error after 70 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# ██████████████████████████████████████████████████████████████████████████ | , 9.44E-08 of error after 71 iterations...
# 2626.924064467197
# ████████████████████████████████████████████████████████████████████████▊ | , 1.05E-07 of error after 101 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# █████████████████████████████████████████████████████████████████████████ | , 8.82E-08 of error after 102 iterations...
# 2334.240283112971
# ████████████████████████████████████████████████████████████████████████▉ | , 1.01E-07 of error after 418 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# █████████████████████████████████████████████████████████████████████████ | , 9.86E-08 of error after 419 iterations...
# 2089.429734607119
# ████████████████████████████████████████████████████████████████████████▉ | , 1.01E-07 of error after 335 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# █████████████████████████████████████████████████████████████████████████ | , 9.76E-08 of error after 336 iterations...
# 1851.2957921782122
# ████████████████████████████████████████████████████████████████████████▊ | , 1.05E-07 of error after 148 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# █████████████████████████████████████████████████████████████████████████ | , 9.57E-08 of error after 149 iterations...
# 1622.1121056972615
# █████████████████████████████████████████████████████████████████████████▎ | , 1.18E-07 of error after 81 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# ██████████████████████████████████████████████████████████████████████████ | , 9.98E-08 of error after 82 iterations...
# 1412.7887454382135
# ████████████████████████████████████████████████████████████████████████▉ | , 1.01E-07 of error after 222 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# █████████████████████████████████████████████████████████████████████████ | , 9.40E-08 of error after 223 iterations...
# 1235.1203103409998
# ████████████████████████████████████████████████████████████████████████▋ | , 1.06E-07 of error after 143 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# █████████████████████████████████████████████████████████████████████████ | , 9.63E-08 of error after 144 iterations...
# 1069.540178302861
# ████████████████████████████████████████████████████████████████████████▊ | , 1.04E-07 of error after 179 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# █████████████████████████████████████████████████████████████████████████ | , 9.74E-08 of error after 180 iterations...
# 919.1994502987541
# ████████████████████████████████████████████████████████████████████████▉ | , 1.01E-07 of error after 646 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# █████████████████████████████████████████████████████████████████████████ | , 9.95E-08 of error after 647 iterations...
# 778.773311199418
# ████████████████████████████████████████████████████████████████████████▊ | , 1.04E-07 of error after 394 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# █████████████████████████████████████████████████████████████████████████ | , 9.98E-08 of error after 395 iterations...
# 640.6039652922323
# ████████████████████████████████████████████████████████████████████████▋ | , 1.06E-07 of error after 205 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# █████████████████████████████████████████████████████████████████████████ | , 9.90E-08 of error after 206 iterations...
# 507.4134168993934
# ████████████████████████████████████████████████████████████████████████▊ | , 1.05E-07 of error after 191 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# █████████████████████████████████████████████████████████████████████████ | , 9.80E-08 of error after 192 iterations...
# 382.59767904064864
# ████████████████████████████████████████████████████████████████████████▉ | , 1.02E-07 of error after 227 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# █████████████████████████████████████████████████████████████████████████ | , 9.63E-08 of error after 228 iterations...
# 265.8669325840096
# █████████████████████████████████████████████████████████████████████████▍ | , 1.13E-07 of error after 87 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# ██████████████████████████████████████████████████████████████████████████ | , 9.69E-08 of error after 88 iterations...
# 155.61283711016497
# ████████████████████████████████████████████████████████████████████████▍  | , 1.40E-07 of error after 37 iterations...C:\Users\rickc\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:636: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
# ██████████████████████████████████████████████████████████████████████████ | , 9.11E-08 of error after 38 iterations...
# 61.25638053840006
#                                                                             | , 2.01E-13 of error after 2 iterations...
# -2.949068806222389e-11
# Stopped as all variance has been extracted after computing 19 PCs.

# %%
print(len(explained_variance))
for variance in range(len(explained_variance)) :
    print(np.sum(explained_variance[:variance + 1]))
print(len(components[0]))
print(np.sum([np.std(common_tokens_only.loc[feature]) for feature in common_tokens_only.index]))
# Out:
# 19
# 538.9083556424556
# 942.0322788228069
# 1282.0759355328025
# 1574.7597168870266
# 1819.5702653928809
# 2057.7042078217896
# 2286.8878943027407
# 2496.2112545617897
# 2673.8796896589993
# 2839.4598216971385
# 2989.8005497012455
# 3130.2266888005834
# 3268.3960347077696
# 3401.5865831006076
# 3526.402320959351
# 3643.13306741599
# 3753.3871628898355
# 3847.7436194616007
# 3909.0000000000305
# 3909
# 3909.0

# %%
# Creating the scatter plot
feature_graph_figure = plt.figure(figsize=(8, 6))
feature_graph = feature_graph_figure.subplots()
coords = [[np.dot(common_tokens_only[author], components[0]), np.dot(common_tokens_only[author], components[1])] for author in common_tokens_only]
feature_graph.scatter([coord[0] for coord in coords], [coord[1] for coord in coords], color='blue', alpha=0.7)
for i, author in enumerate(common_tokens_only.columns):
    feature_graph.annotate(author, coords[i])
feature_graph.set_xlabel("PC1")
feature_graph.set_ylabel("PC2")
feature_graph.grid(True)
feature_graph_figure.show()
# Out:
#                                                                                                                      |
# C:\Users\rickc\AppData\Local\Temp\ipykernel_5176\611624418.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   feature_graph_figure.show()

# %%
print(np.linalg.norm(common_tokens_only['claude-v1'] - common_tokens_only['claude-instant-v1']))
print(np.dot(common_tokens_only['claude-v1'], common_tokens_only['claude-instant-v1']))
print(np.linalg.norm(common_tokens_only['claude-v1'] - common_tokens_only['alpaca-13b']))
print(np.dot(common_tokens_only['claude-v1'], common_tokens_only['alpaca-13b']))
print(np.linalg.norm(common_tokens_only['alpaca-13b'] - common_tokens_only['palm-2']))
print(np.dot(common_tokens_only['alpaca-13b'], common_tokens_only['palm-2']))
# Out:
# 71.38743839876037
# 2076.6495827198464
# 93.44522975893871
# -148.52134278960563
# 92.57481995488861
# 43.60922692466244

# %%
np.linalg.norm(common_tokens_only['claude-v1'] - common_tokens_only['llama-13b'])
# Out:
# np.float64(113.37478908947125)

# %%
# !pip freeze
# Out:
# aiohappyeyeballs==2.4.4
# aiohttp==3.11.10
# aiosignal==1.3.2
# anyio==4.1.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==2.4.1
# async-lru==2.0.4
# attrs==23.1.0
# Babel==2.13.1
# beautifulsoup4==4.12.2
# bleach==6.1.0
# certifi==2023.11.17
# cffi==1.16.0
# charset-normalizer==3.3.2
# colorama==0.4.6
# comm==0.2.0
# contourpy==1.3.1
# cycler==0.12.1
# datasets==3.2.0
# debugpy==1.8.0
# decorator==5.1.1
# defusedxml==0.7.1
# dill==0.3.8
# distlib==0.3.8
# executing==2.0.1
# fastjsonschema==2.19.0
# filelock==3.15.4
# fonttools==4.55.3
# fqdn==1.5.1
# frozenlist==1.5.0
# fsspec==2024.9.0
# h11==0.14.0
# huggingface-hub==0.26.5
# idna==3.4
# ipykernel==6.27.0
# ipython==8.17.2
# ipywidgets==8.1.1
# isoduration==20.11.0
# jedi==0.19.1
# Jinja2==3.1.2
# joblib==1.4.2
# json5==0.9.14
# jsonpointer==2.4
# jsonschema==4.20.0
# jsonschema-specifications==2023.11.1
# jupyter==1.0.0
# jupyter-console==6.6.3
# jupyter-events==0.9.0
# jupyter-lsp==2.2.0
# jupyter_client==8.6.0
# jupyter_core==5.5.0
# jupyter_server==2.10.1
# jupyter_server_terminals==0.4.4
# jupyterlab==4.0.9
# jupyterlab-widgets==3.0.9
# jupyterlab_pygments==0.3.0
# jupyterlab_server==2.25.2
# kiwisolver==1.4.7
# MarkupSafe==2.1.3
# matplotlib==3.10.0
# matplotlib-inline==0.1.6
# mistune==3.0.2
# multidict==6.1.0
# multiprocess==0.70.16
# nbclient==0.9.0
# nbconvert==7.11.0
# nbformat==5.9.2
# nest-asyncio==1.5.8
# notebook==7.0.6
# notebook_shim==0.2.3
# numpy==2.2.0
# outcome==1.3.0.post0
# overrides==7.4.0
# packaging==23.2
# pandas==2.2.3
# pandocfilters==1.5.0
# parso==0.8.3
# pillow==11.0.0
# pipenv==2024.0.1
# platformdirs==4.0.0
# prometheus-client==0.19.0
# prompt-toolkit==3.0.41
# propcache==0.2.1
# psutil==5.9.6
# pure-eval==0.2.2
# pyarrow==18.1.0
# pycparser==2.21
# pygame==2.5.2
# Pygments==2.17.2
# pyparsing==3.2.0
# PySocks==1.7.1
# python-dateutil==2.8.2
# python-json-logger==2.0.7
# pytz==2024.2
# pywin32==306
# pywinpty==2.0.12
# PyYAML==6.0.1
# pyzmq==25.1.1
# qtconsole==5.5.1
# QtPy==2.4.1
# referencing==0.31.0
# requests==2.32.3
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rpds-py==0.13.1
# scikit-learn==1.6.0
# scipy==1.14.1
# selenium==4.15.2
# Send2Trash==1.8.2
# setuptools==69.0.2
# six==1.16.0
# sniffio==1.3.0
# sortedcontainers==2.4.0
# soupsieve==2.5
# stack-data==0.6.3
# terminado==0.18.0
# threadpoolctl==3.5.0
# tinycss2==1.2.1
# tornado==6.3.3
# tqdm==4.67.1
# traitlets==5.13.0
# trio==0.23.1
# trio-websocket==0.11.1
# types-python-dateutil==2.8.19.14
# typing_extensions==4.12.2
# tzdata==2024.2
# uri-template==1.3.0
# urllib3==2.1.0
# virtualenv==20.26.3
# wcwidth==0.2.12
# webcolors==1.13
# webencodings==0.5.1
# websocket-client==1.6.4
# widgetsnbextension==4.0.9
# wsproto==1.2.0
# xxhash==3.5.0
# yarl==1.18.3
